# %% [markdown]
# ## Gender guesser do file
#
# #### Purpose: take list of contacts provided by GIZ and guess their gender based on first names
# Outline:
# Part 1: Set up paths, import necessary packages
# Part 2: Load datasets (mailing lists provided by GIZ) and merge
# Part 3: Clean data and run gender-guesser package
# Part 4: (Still under construction!!!) Load existing lists of Arabic names to guess gender of remaining names
# Part 5: Export results

# %% [markdown]
# ## Part 1
# #### Download any necessary packages, import and set up paths

# %%
## Install these packages if you don't have them already (remove the #)

#!pip install gender_guesser
#!pip install earthpy

# %%
import csv
import pandas as pd
import re
import gender_guesser.detector as gender
import os
import earthpy as et

# %%
github_path = os.path.join(et.io.HOME, "Documents","GitHub","giz-pema-ecommerce","sampling-email-experiment")
gdrive_path = os.path.join(et.io.HOME, "Google Drive","My Drive", "Research_GIZ_Tunisia_exportpromotion","1. Intervention I – E-commerce","data","0-sampling-email-experiment")
os.chdir(my_path)

# %% [markdown]
# ## Part 2
#
# #### Load datasets and merge
# (Prior to this, all datasets were saved in .csv format)

# %%
## First PEMA dataset

pema = pd.read_csv(os.path.join(gdrive_path,'raw','BD Pema II.csv'), dtype='string' )
pema.rename(columns={'Entreprises': 'firmname', 'Prénom et nom': 'name', 'Email': 'email'}, inplace=True)
pema
# Out:
#             firmname               name                            email
# 0             3Dwave        Ferid kamel             feridkamel@gmail.com
# 1           ABAPLAST     Akram Ben amor               abaplast@topnet.tn
# 2    ABIN CONSULTING         Elyes Grar              elyesgrar@gmail.com
# 3                ABP    Ayda Bouassida          aydabouassidaa@gmail.com
# 4            ABSHORE        Asma Mechri          asma.mechri@abshore.com
# ..               ...                ...                              ...
# 622     CLOUD TEMPLE         Amina brik      Amina.BRIK@cloud-temple.com
# 623     CLOUD TEMPLE     Ibtissem dhiab  ibtissem.DHIAB@cloud-temple.com
# 624           Wevioo      Amine Aloulou         Amine.Aloulou@wevioo.com
# 625           GET'IT  Nourchene Bouissa       nbouissa@getit-tunisia.com
# 626           GET'IT      Khaled Mehiri            kmehiri@aramis.com.tn
#
# [627 rows x 3 columns]

# %% [markdown]
# ##### This one needs a bit of cleaning before it can be merged

# %%
pema['name'] = pema['name'].str.strip()
pema[['firstname','lastname']] = pema["name"].str.split(" ", 1, expand=True)
pema['origin'] = 'pema'
pema
# Out:
#             firmname               name                            email  \
# 0             3Dwave        Ferid kamel             feridkamel@gmail.com
# 1           ABAPLAST     Akram Ben amor               abaplast@topnet.tn
# 2    ABIN CONSULTING         Elyes Grar              elyesgrar@gmail.com
# 3                ABP     Ayda Bouassida         aydabouassidaa@gmail.com
# 4            ABSHORE        Asma Mechri          asma.mechri@abshore.com
# ..               ...                ...                              ...
# 622     CLOUD TEMPLE         Amina brik      Amina.BRIK@cloud-temple.com
# 623     CLOUD TEMPLE     Ibtissem dhiab  ibtissem.DHIAB@cloud-temple.com
# 624           Wevioo      Amine Aloulou         Amine.Aloulou@wevioo.com
# 625           GET'IT  Nourchene Bouissa       nbouissa@getit-tunisia.com
# 626           GET'IT      Khaled Mehiri            kmehiri@aramis.com.tn
#
#      firstname   lastname origin
# 0        Ferid      kamel   pema
# 1        Akram   Ben amor   pema
# 2        Elyes       Grar   pema
# 3         Ayda  Bouassida   pema
# 4         Asma     Mechri   pema
# ..         ...        ...    ...
# 622      Amina       brik   pema
# 623   Ibtissem      dhiab   pema
# 624      Amine    Aloulou   pema
# 625  Nourchene    Bouissa   pema
# 626     Khaled     Mehiri   pema
#
# [627 rows x 6 columns]

# %%
# Second PEMA dataset

pema2 = pd.read_csv(os.path.join(gdrive_path,'raw','BD Event lancement PEMA II.csv'), skiprows=3, dtype='string' )
pema2.rename(columns={'Nom d’utilisateur (nom original)': 'name', 'Prénom': 'firstname', 'Nom de famille': 'lastname', 'Adresse électronique': 'email'}, inplace=True)
pema2 = pema2[['name','firstname', 'lastname', 'email']]
pema2['origin'] = 'pema2'
pema2
# Out:
#                 name     firstname      lastname  \
# 0       Mohamed Anis  Mohamed Anis  BEN ROMDHANE
# 1        nabil zarai         nabil         zarai
# 2              Fatma         Fatma      Gattoufi
# 3        Noura Aloui         Noura         Aloui
# 4               Emna          Emna       JEMMALI
# ..               ...           ...           ...
# 658     Sihem Hssini         Sihem        Hssini
# 659  RAFIKA BENHLOUA        RAFIKA      BENHLOUA
# 660    Amira M'barek         Amira       M'barek
# 661    taboubi aymen       taboubi         aymen
# 662             <NA>          <NA>          <NA>
#
#                                           email origin
# 0    anis.benromdhane@geomatics-engineering.com  pema2
# 1                                nabil@naza.dev  pema2
# 2                        fattoumagatt@gmail.com  pema2
# 3                         nawaranour67@yahoo.fr  pema2
# 4                        emnajemmali1@gmail.com  pema2
# ..                                          ...    ...
# 658                  soussou.sassouki@gmail.com  pema2
# 659                       info.pharmin@yahoo.fr  pema2
# 660                         export@topoliva.com  pema2
# 661                  ataboubi@advanstunisie.com  pema2
# 662                                        <NA>  pema2
#
# [663 rows x 5 columns]

# %%
# API dataset

api = pd.read_csv(os.path.join(gdrive_path,'raw','APII-BD ApiiGizAfrica.csv'), dtype='string' )
api.rename(columns={'raison_sociale': 'firmname', 'responsable': 'name'}, inplace=True)
api = api[['firmname','name', 'email']]
api['origin'] = 'api'
api
# Out:
#                            firmname                      name  \
# 0     STE METLINE RAS JEBEL TEXTILE              FATHI MOUSSA
# 1             STE MODERNE D'ELEVAGE              HATEM BACCAR
# 2              AKWEL MATEUR TUNISIA          YASSINE TAGHOUTI
# 3              STE BEN AISSA FRERES             ALI BEN AISSA
# 4                          ALMES II  MOHAMED BECHIR EL KHIARI
# ...                             ...                       ...
# 5064           ABDESSATAR BEN SALHA      ABDESSATAR BEN SALHA
# 5065      STE HASNA CUIR COLLECTION         INSAF BEN HASSINE
# 5066   STE CHARCOLIVE INTERNATIONAL           ALEXANDRE REKIK
# 5067                    STE STAMROP            DIDIER GERMAIN
# 5068               STE CABLIT LAMEC    ZARANTONELLO FRANCESCO
#
#                                      email origin
# 0                     meratex.fm@gmail.com    api
# 1                            sme@planet.tn    api
# 2     yassinetaghouti@akwel-automotive.com    api
# 3                 benaissa_freres@yahoo.fr    api
# 4              almes.mateur@poulina.com.tn    api
# ...                                    ...    ...
# 5064                                  <NA>    api
# 5065                                  <NA>    api
# 5066                   alexrekik@gmail.com    api
# 5067              alexis.stamrop@gmail.com    api
# 5068               dissem.compta@gmail.com    api
#
# [5069 rows x 4 columns]

# %%
# Split name into first and last

api['name'] = api['name'].str.strip()
api[['firstname','lastname']] = api["name"].str.split(" ", 1, expand=True)
api
# Out:
#                            firmname                      name  \
# 0     STE METLINE RAS JEBEL TEXTILE              FATHI MOUSSA
# 1             STE MODERNE D'ELEVAGE              HATEM BACCAR
# 2              AKWEL MATEUR TUNISIA          YASSINE TAGHOUTI
# 3              STE BEN AISSA FRERES             ALI BEN AISSA
# 4                          ALMES II  MOHAMED BECHIR EL KHIARI
# ...                             ...                       ...
# 5064           ABDESSATAR BEN SALHA      ABDESSATAR BEN SALHA
# 5065      STE HASNA CUIR COLLECTION         INSAF BEN HASSINE
# 5066   STE CHARCOLIVE INTERNATIONAL           ALEXANDRE REKIK
# 5067                    STE STAMROP            DIDIER GERMAIN
# 5068               STE CABLIT LAMEC    ZARANTONELLO FRANCESCO
#
#                                      email origin     firstname  \
# 0                     meratex.fm@gmail.com    api         FATHI
# 1                            sme@planet.tn    api         HATEM
# 2     yassinetaghouti@akwel-automotive.com    api       YASSINE
# 3                 benaissa_freres@yahoo.fr    api           ALI
# 4              almes.mateur@poulina.com.tn    api       MOHAMED
# ...                                    ...    ...           ...
# 5064                                  <NA>    api    ABDESSATAR
# 5065                                  <NA>    api         INSAF
# 5066                   alexrekik@gmail.com    api     ALEXANDRE
# 5067              alexis.stamrop@gmail.com    api        DIDIER
# 5068               dissem.compta@gmail.com    api  ZARANTONELLO
#
#               lastname
# 0               MOUSSA
# 1               BACCAR
# 2             TAGHOUTI
# 3            BEN AISSA
# 4     BECHIR EL KHIARI
# ...                ...
# 5064         BEN SALHA
# 5065       BEN HASSINE
# 5066             REKIK
# 5067           GERMAIN
# 5068         FRANCESCO
#
# [5069 rows x 6 columns]

# %%
# Plenty of missing emails, drop

api = api[api['email'].notna()]
api.shape
# Out:
# (4016, 6)

# %%
# Merge

frames = [pema, pema2, api]

df = pd.concat(frames)
df
# Out:
#                             firmname                    name  \
# 0                             3Dwave             Ferid kamel
# 1                           ABAPLAST          Akram Ben amor
# 2                    ABIN CONSULTING              Elyes Grar
# 3                                ABP          Ayda Bouassida
# 4                            ABSHORE             Asma Mechri
# ...                              ...                     ...
# 5059                   MAISON NATURE          OUSSAMA BRAHEM
# 5062  SOCIETE HAMMAMI KHALED ET FILS          KHALED HAMMAMI
# 5066    STE CHARCOLIVE INTERNATIONAL         ALEXANDRE REKIK
# 5067                     STE STAMROP          DIDIER GERMAIN
# 5068                STE CABLIT LAMEC  ZARANTONELLO FRANCESCO
#
#                            email     firstname   lastname origin
# 0           feridkamel@gmail.com         Ferid      kamel   pema
# 1             abaplast@topnet.tn         Akram   Ben amor   pema
# 2            elyesgrar@gmail.com         Elyes       Grar   pema
# 3       aydabouassidaa@gmail.com          Ayda  Bouassida   pema
# 4        asma.mechri@abshore.com          Asma     Mechri   pema
# ...                          ...           ...        ...    ...
# 5059     contact@maisonnature.tn       OUSSAMA     BRAHEM    api
# 5062  proplast.tunisie@gmail.com        KHALED    HAMMAMI    api
# 5066         alexrekik@gmail.com     ALEXANDRE      REKIK    api
# 5067    alexis.stamrop@gmail.com        DIDIER    GERMAIN    api
# 5068     dissem.compta@gmail.com  ZARANTONELLO  FRANCESCO    api
#
# [5306 rows x 6 columns]

# %% [markdown]
# ## Part 3
# #### Clean data and run gender-guesser package

# %%
# Remove duplicates

df = df.drop_duplicates(subset='email', keep="first")
df.shape
# Out:
# (5002, 6)

# %%
# Lower case first names: 

df['firstname'] = df['firstname'].str.lower()

# Recapitalize: 

df['firstname'] = df['firstname'].str.capitalize()

# Lower case firm names: 

df['firmname'] = df['firmname'].str.lower()

# Trim first name

df['firstname'] = df['firstname'].str.strip()

# Normalize key accents

repl = str.maketrans(
    "áéúíóçèîêàöëù",
    "aeuioceieaoeu"
)

df['firstname'] = df['firstname'].str.translate(repl)

df
# Out:
# <ipython-input-16-cfd79949f40f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['firstname'] = df['firstname'].str.lower()
# <ipython-input-16-cfd79949f40f>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['firstname'] = df['firstname'].str.capitalize()
# <ipython-input-16-cfd79949f40f>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['firmname'] = df['firmname'].str.lower()
# <ipython-input-16-cfd79949f40f>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['firstname'] = df['firstname'].str.strip()
# <ipython-input-16-cfd79949f40f>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['firstname'] = df['firstname'].str.translate(repl)
#                             firmname                    name  \
# 0                             3dwave             Ferid kamel
# 1                           abaplast          Akram Ben amor
# 2                    abin consulting              Elyes Grar
# 3                                abp          Ayda Bouassida
# 4                            abshore             Asma Mechri
# ...                              ...                     ...
# 5059                   maison nature          OUSSAMA BRAHEM
# 5062  societe hammami khaled et fils          KHALED HAMMAMI
# 5066    ste charcolive international         ALEXANDRE REKIK
# 5067                     ste stamrop          DIDIER GERMAIN
# 5068                ste cablit lamec  ZARANTONELLO FRANCESCO
#
#                            email     firstname   lastname origin
# 0           feridkamel@gmail.com         Ferid      kamel   pema
# 1             abaplast@topnet.tn         Akram   Ben amor   pema
# 2            elyesgrar@gmail.com         Elyes       Grar   pema
# 3       aydabouassidaa@gmail.com          Ayda  Bouassida   pema
# 4        asma.mechri@abshore.com          Asma     Mechri   pema
# ...                          ...           ...        ...    ...
# 5059     contact@maisonnature.tn       Oussama     BRAHEM    api
# 5062  proplast.tunisie@gmail.com        Khaled    HAMMAMI    api
# 5066         alexrekik@gmail.com     Alexandre      REKIK    api
# 5067    alexis.stamrop@gmail.com        Didier    GERMAIN    api
# 5068     dissem.compta@gmail.com  Zarantonello  FRANCESCO    api
#
# [5002 rows x 6 columns]

# %% [markdown]
# ##### Run the gender guesser

# %%
d = gender.Detector()

df['gender'] = df['firstname'].apply(lambda x: d.get_gender(x))
df['gender'].value_counts()
# Out:
# <ipython-input-17-f76093c9a103>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gender'] = df['firstname'].apply(lambda x: d.get_gender(x))
# male             2847
# unknown          1626
# female            489
# mostly_female      18
# mostly_male        14
# andy                8
# Name: gender, dtype: int64

# %% [markdown]
# ##### Now the same but on the surnames

# %%
# Lower case first names: 

df['lastname'] = df['lastname'].str.lower()

# Recapitalize: 

df['lastname'] = df['lastname'].str.capitalize()

# Trim first name

df['lastname'] = df['lastname'].str.strip()

# Normalize key accents

repl = str.maketrans(
    "áéúíóçèîêàöëù",
    "aeuioceieaoeu"
)

df['lastname'] = df['lastname'].str.translate(repl)

df

df['gender1'] = df['lastname'].apply(lambda x: d.get_gender(x))
df['gender1'].value_counts()
# Out:
# <ipython-input-18-e27b7dad0f32>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lastname'] = df['lastname'].str.lower()
# <ipython-input-18-e27b7dad0f32>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lastname'] = df['lastname'].str.capitalize()
# <ipython-input-18-e27b7dad0f32>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lastname'] = df['lastname'].str.strip()
# <ipython-input-18-e27b7dad0f32>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lastname'] = df['lastname'].str.translate(repl)
# <ipython-input-18-e27b7dad0f32>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gender1'] = df['lastname'].apply(lambda x: d.get_gender(x))
# unknown          4577
# male              355
# female             60
# mostly_female       5
# andy                4
# mostly_male         1
# Name: gender1, dtype: int64

# %% [markdown]
# ## Part 4 [INCOMPLETE!]
# #### Load existing lists of Arabic names to guess gender of remaining names
# #### Currently not used – these datasets don't change anything atm
#
# This still leaves about a third of names as 'Unknow'. Let's use some other approaches to fix this.

# %%
# Pick only the ones unknown

grouped = df.groupby(['gender','gender1'])
df_unknown = grouped.get_group(("unknown", "unknown"))
df_unknown.shape
# Out:
# (1433, 8)

# %%
# One quick fix, many names start with 'Mr' and are male: 

#mask = (df_unknown['firstname'] == 'Mr') 
#df_unknown['gender'][mask] = 'male'

fnames = {'Mr' : "male"}

df_unknown['gender2'] = df_unknown['firstname'].map(fnames)
df_unknown['gender2'].value_counts()
# Out:
# <ipython-input-20-b34554848a37>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_unknown['gender2'] = df_unknown['firstname'].map(fnames)
# male    9
# Name: gender2, dtype: int64

# %%
# Load list of names from French gov't 

fra_names = pd.read_csv(os.path.join(gdrive_path,'raw','names_france.csv'), encoding= "utf-8")
fra_names.rename(columns={'01_prenom': 'names', '02_genre': 'gender3', '03_langage': 'language', '04_fréquence': 'freq'}, inplace=True)
fra_names
# Out:
#            names gender3          language  freq
# 0        aaliyah       f  english (modern)   0.0
# 1         aapeli       m           finnish   0.0
# 2           aapo       m           finnish   0.0
# 3          aaren     m,f           english   0.0
# 4          aarne       m           finnish   0.0
# ...          ...     ...               ...   ...
# 11622        zvi       m            jewish   0.1
# 11623   zvonimir       m          croatian   0.0
# 11624  zvonimira       f          croatian   0.0
# 11625     zvonko       m          croatian   0.0
# 11626    zygmunt       m            polish   0.0
#
# [11627 rows x 4 columns]

# %% [markdown]
# Some cleaning is needed

# %%
# Trim names

fra_names['names'] = fra_names['names'].str.strip()

fra_names[['firstname','lastname']] = fra_names['names'].str.split(" ", 1, expand=True)


# Normalize key accents

repl = str.maketrans(
    "áéúíóçèîêàöëù",
    "aeuioceieaoeu"
)

fra_names['firstname'] = fra_names['firstname'].str.translate(repl)

fra_names
# Out:
#            names gender3          language  freq  firstname lastname
# 0        aaliyah       f  english (modern)   0.0    aaliyah     None
# 1         aapeli       m           finnish   0.0     aapeli     None
# 2           aapo       m           finnish   0.0       aapo     None
# 3          aaren     m,f           english   0.0      aaren     None
# 4          aarne       m           finnish   0.0      aarne     None
# ...          ...     ...               ...   ...        ...      ...
# 11622        zvi       m            jewish   0.1        zvi     None
# 11623   zvonimir       m          croatian   0.0   zvonimir     None
# 11624  zvonimira       f          croatian   0.0  zvonimira     None
# 11625     zvonko       m          croatian   0.0     zvonko     None
# 11626    zygmunt       m            polish   0.0    zygmunt     None
#
# [11627 rows x 6 columns]

# %%
# Merge with our dataframe

df_french = pd.merge(df_unknown,fra_names, on = 'firstname', how="left")
df_french.shape
# Out:
# (1433, 14)

# %%
# Load list of names from Kalmasoft

names = pd.read_csv(os.path.join(gdrive_path,'raw','KDBGIVE.txt'), skiprows=81, sep='\t+')
names = names[['Roman', 'Gender']]
names.rename(columns={'Roman': 'capname', 'Gender': 'Gender'}, inplace=True)
names.head()
# Out:
# <ipython-input-67-f05d4111bd44>:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   names = pd.read_csv('/Users/teofirpo/Desktop/KDBGIVE.txt', skiprows=81, sep='\t+')
#       capname Gender
# 0   Abosaymah      M
# 1  Aboussaima      M
# 2    Albastji      M
# 3   Elbestdji      M
# 4   Albastaji      M

# %%
# Merge with our dataframe

df_arabic = pd.merge(df_french,names, on = 'capname', how="left")

# %% [markdown]
# ## Part 5:
# #### Export files
# Using Excel to avoid spacing issues

# %%
# Export to Excel

df.to_excel(os.path.join(gdrive_path,'intermediate','giz_contact_list.xlsx'))
